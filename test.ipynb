# %%
from brian2 import *
import numpy as np
# %matplotlib inline

# %%
num_inputs = 1
input_rate = 10*Hz
P = PoissonGroup(num_inputs, rates=input_rate)
M = S(P)
run(1*second)

# %%
plot()

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''

G = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2,0]
G.tau = [10, 100]*ms

# Comment these two lines out to see what happens without Synapses
S = Synapses(G, G, on_pre='v_post += 0.2')
S.connect(i=0, j=1)

M = StateMonitor(G, 'v', record=True)

run(100*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
xlabel('Time (ms)')
ylabel('v')
legend()

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''

G = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2,0]
G.tau = [10, 100]*ms

F = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
F.I = [2,0]
F.tau = [10, 100]*ms

D = StateMonitor(G, 'v', record=True)
# Comment these two lines out to see what happens without Synapses
S = Synapses(G, G, on_pre='v_post += 0.2')
S.connect(i=0, j=1)

M = StateMonitor(G, 'v', record=True)

run(100*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
#plot(D.t/ms, D.v[0], label='Neuron 01')
plot(D.t/ms, D.v[1], label='Neuron 11')
xlabel('Time (ms)')
ylabel('v')
legend()

# %%
#plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
#plot(D.t/ms, D.v[0], label='Neuron 01')
plot(D.t/ms, D.v[1], label='Neuron 11')
xlabel('Time (ms)')
ylabel('v')
legend()

# %%
plot()

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''

G = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2,0]
G.tau = [10, 100]*ms

# Comment these two lines out to see what happens without Synapses
S = Synapses(G, G, on_pre='v_post += 0.2')
S.connect(i=0, j=1)

M = StateMonitor(G, 'v', record=True)

run(100*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
xlabel('Time (ms)')
ylabel('v')
legend()

# %%
start_scope()

eqs = '''
dv/dt = (I-v)/tau : 1
I : 1
tau : second
'''

G = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
G.I = [2,0]
G.tau = [10, 100]*ms

F = NeuronGroup(2, eqs, threshold='v>1', reset='v = 0', method='exact')
F.I = [2,0]
F.tau = [10, 100]*ms

D = StateMonitor(G, 'v', record=True)
# Comment these two lines out to see what happens without Synapses
S = Synapses(G, G, on_pre='v_post += 0.2')
S.connect(i=0, j=1)

M = StateMonitor(G, 'v', record=True)

run(100*ms)

plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
#plot(D.t/ms, D.v[0], label='Neuron 01')
plot(D.t/ms, D.v[1], label='Neuron 11')
xlabel('Time (ms)')
ylabel('v')
legend()

# %%
#plot(M.t/ms, M.v[0], label='Neuron 0')
plot(M.t/ms, M.v[1], label='Neuron 1')
#plot(D.t/ms, D.v[0], label='Neuron 01')
plot(D.t/ms, D.v[1], label='Neuron 11')
xlabel('Time (ms)')
ylabel('v')
legend()
